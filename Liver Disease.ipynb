# %% [markdown]
# ## Import Basic Package

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score,  roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import VotingClassifier
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Data

# %%
liver = pd.read_csv('liver.csv')

# %%
liver.head()
# Out:
#    age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 0   65  Female            0.7               0.1           187       16
# 1   62    Male           10.9               5.5           699       64
# 2   62    Male            7.3               4.1           490       60
# 3   58    Male            1.0               0.4           182       14
# 4   72    Male            3.9               2.0           195       27
#
#    ag_ratio  sgpt  sgot  alkphos  is_patient
# 0        18   6.8   3.3     0.90           1
# 1       100   7.5   3.2     0.74           1
# 2        68   7.0   3.3     0.89           1
# 3        20   6.8   3.4     1.00           1
# 4        59   7.3   2.4     0.40           1

# %%
liver.sample(5)
# Out:
#      age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 60    31  Female            0.8               0.2           158       21
# 193   49    Male            1.3               0.4           206       30
# 532   62    Male            0.7               0.2           162       12
# 336   75    Male            6.7               3.6           458      198
# 413   48    Male            0.7               0.2           208       15
#
#      ag_ratio  sgpt  sgot  alkphos  is_patient
# 60         16   6.0   3.0     1.00           1
# 193        25   6.0   3.1     1.06           2
# 532        17   8.2   3.2     0.60           2
# 336       143   6.2   3.2     1.00           1
# 413        30   4.6   2.1     0.80           2

# %%
liver.tail()
# Out:
#      age gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 578   60   Male            0.5               0.1           500       20
# 579   40   Male            0.6               0.1            98       35
# 580   52   Male            0.8               0.2           245       48
# 581   31   Male            1.3               0.5           184       29
# 582   38   Male            1.0               0.3           216       21
#
#      ag_ratio  sgpt  sgot  alkphos  is_patient
# 578        34   5.9   1.6     0.37           2
# 579        31   6.0   3.2     1.10           1
# 580        49   6.4   3.2     1.00           1
# 581        32   6.8   3.4     1.00           1
# 582        24   7.3   4.4     1.50           2

# %%
liver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               583 non-null    int64
#  1   gender            583 non-null    object
#  2   tot_bilirubin     583 non-null    float64
#  3   direct_bilirubin  583 non-null    float64
#  4   tot_proteins      583 non-null    int64
#  5   albumin           583 non-null    int64
#  6   ag_ratio          583 non-null    int64
#  7   sgpt              583 non-null    float64
#  8   sgot              583 non-null    float64
#  9   alkphos           579 non-null    float64
#  10  is_patient        583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
# Checking for missing data
liver.isnull().sum()
# Out:
# age                 0
# gender              0
# tot_bilirubin       0
# direct_bilirubin    0
# tot_proteins        0
# albumin             0
# ag_ratio            0
# sgpt                0
# sgot                0
# alkphos             4
# is_patient          0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
liver.describe()
# Out:
#               age  tot_bilirubin  direct_bilirubin  tot_proteins      albumin  \
# count  583.000000     583.000000        583.000000    583.000000   583.000000
# mean    44.746141       3.298799          1.486106    290.576329    80.713551
# std     16.189833       6.209522          2.808498    242.937989   182.620356
# min      4.000000       0.400000          0.100000     63.000000    10.000000
# 25%     33.000000       0.800000          0.200000    175.500000    23.000000
# 50%     45.000000       1.000000          0.300000    208.000000    35.000000
# 75%     58.000000       2.600000          1.300000    298.000000    60.500000
# max     90.000000      75.000000         19.700000   2110.000000  2000.000000
#
#           ag_ratio        sgpt        sgot     alkphos  is_patient
# count   583.000000  583.000000  583.000000  579.000000  583.000000
# mean    109.910806    6.483190    3.141852    0.947064    1.286449
# std     288.918529    1.085451    0.795519    0.319592    0.452490
# min      10.000000    2.700000    0.900000    0.300000    1.000000
# 25%      25.000000    5.800000    2.600000    0.700000    1.000000
# 50%      42.000000    6.600000    3.100000    0.930000    1.000000
# 75%      87.000000    7.200000    3.800000    1.100000    2.000000
# max    4929.000000    9.600000    5.500000    2.800000    2.000000

# %%
liver[liver['alkphos'].isnull()]
# Out:
#      age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 209   45  Female            0.9               0.3           189       23
# 241   51    Male            0.8               0.2           230       24
# 253   35  Female            0.6               0.2           180       12
# 312   27    Male            1.3               0.6           106       25
#
#      ag_ratio  sgpt  sgot  alkphos  is_patient
# 209        33   6.6   3.9      NaN           1
# 241        46   6.5   3.1      NaN           1
# 253        15   5.2   2.7      NaN           2
# 312        54   8.5   4.8      NaN           2

# %%
# missing data imputation
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
liver['alkphos']=imp.fit_transform(liver[['alkphos']])

# %%
# Check the missing data again
liver['alkphos'].isnull().sum()
# Out:
# 0

# %%
# Encoding gender
liver['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
liver['gender'] = liver['gender'].apply(lambda x:1 if x == 'Male' else 0) #female = 0 and male = 1

# %%
# check geder values
liver['gender'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
liver.sample(5)
# Out:
#      age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 164   39       1            1.9               0.9           180       42
# 306   48       1            1.6               1.0           588       74
# 253   35       0            0.6               0.2           180       12
# 311   54       0           23.2              12.6           574       43
# 567   52       1            2.7               1.4           251       20
#
#      ag_ratio  sgpt  sgot   alkphos  is_patient
# 164        62   7.4   4.3  1.380000           1
# 306       113   7.3   2.4  0.400000           1
# 253        15   5.2   2.7  0.947064           2
# 311        47   7.2   3.5  0.900000           1
# 567        40   6.0   1.7  0.390000           1

# %% [markdown]
# ## Data Visulaization

# %%
liver.corr().style.background_gradient(cmap='PuBu')
# Out:
# <style  type="text/css" >
# #T_b11f275e_2548_11ed_9b45_d8d09003af97row0_col0,#T_b11f275e_2548_11ed_9b45_d8d09003af97row1_col1,#T_b11f275e_2548_11ed_9b45_d8d09003af97row2_col2,#T_b11f275e_2548_11ed_9b45_d8d09003af97row3_col3,#T_b11f275e_2548_11ed_9b45_d8d09003af97row4_col4,#T_b11f275e_2548_11ed_9b45_d8d09003af97row5_col5,#T_b11f275e_2548_11ed_9b45_d8d09003af97row6_col6,#T_b11f275e_2548_11ed_9b45_d8d09003af97row7_col7,#T_b11f275e_2548_11ed_9b45_d8d09003af97row8_col8,#T_b11f275e_2548_11ed_9b45_d8d09003af97row9_col9,#T_b11f275e_2548_11ed_9b45_d8d09003af97row10_col10{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97

#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row2_col6,#T_b11f275e_2548_11ed_9b45_d8d09003af97row10_col8{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row2_col7{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row2_col8{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row2_col9,#T_b11f275e_2548_11ed_9b45_d8d09003af97row2_col10{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row3_col0{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row3_col1{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row3_col2{
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row3_col4,#T_b11f275e_2548_11ed_9b45_d8d09003af97row7_col9{
#             background-color:  #a4bcda;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row3_col5{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row3_col7,#T_b11f275e_2548_11ed_9b45_d8d09003af97row6_col1{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row3_col8,#T_b11f275e_2548_11ed_9b45_d8d09003af97row3_col9{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row4_col0,#T_b11f275e_2548_11ed_9b45_d8d09003af97row4_col6{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row4_col1,#T_b11f275e_2548_11ed_9b45_d8d09003af97row7_col0{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row4_col2{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row4_col3,#T_b11f275e_2548_11ed_9b45_d8d09003af97row5_col3{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row4_col5{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row4_col8{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row4_col10{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row5_col0,#T_b11f275e_2548_11ed_9b45_d8d09003af97row6_col8{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row5_col1{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d09003af97row5_col4{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_b11f275e_2548_11ed_9b45_d8d0900

# %%
plt.figure(figsize= (12,8))
sns.barplot(x = 'gender', y = 'is_patient', data = liver ,palette='Pastel1')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='is_patient'>

# %% [markdown]
# ## Splitting The Data

# %%
X = liver.drop('is_patient', axis=1)
y = liver['is_patient'].values

X_train, X_test, y_train, y_test = train_test_split(
                                    X, y,
                                    test_size= 0.3,
                                    random_state= 1)

# %% [markdown]
# ## Scaling the data

# %%
scaler=StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Built Models

# %%
# Instantiate logreg
logreg = LogisticRegression(random_state=1)

# Instantiate knn
knn = KNN(n_neighbors=27)

# Instantiate dt
dt = DecisionTreeClassifier(min_samples_leaf= 0.13, 
                            random_state=1)

# Define the list classifiers
classifiers = [('Logistic Regression', logreg), 
               ('K Nearest Neighbours', knn), 
               ('Classification Tree', dt)]

# %%
# Iterate over the pre-defined list of classifiers
for clf_name, clf in classifiers:    
 
    # Fit clf to the training set
    clf.fit(X_train, y_train)    
   
    # Predict y_pred
    y_pred = clf.predict(X_test)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_pred, y_test) 
   
    # Evaluate clf's accuracy on the test set
    print('{:20}: {:.3f}'.format(clf_name,  accuracy))
# Out:
# Logistic Regression : 0.726
# K Nearest Neighbours: 0.720
# Classification Tree : 0.726

# %%
# Import VotingClassifier from sklearn.ensemble
from sklearn.ensemble import VotingClassifier

# Instantiate a VotingClassifier vc
vc = VotingClassifier(estimators=classifiers)     

# Fit vc to the training set
vc.fit(X_train, y_train)   

# Evaluate the test set predictions
y_pred = vc.predict(X_test)

# Calculate accuracy score
accuracy = accuracy_score(y_pred, y_test)
print('Voting Classifier: {:.3f}'.format(accuracy))
# Out:
# Voting Classifier: 0.737
